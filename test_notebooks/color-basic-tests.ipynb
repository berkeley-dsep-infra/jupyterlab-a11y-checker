# %% [markdown]
# # Basic Tests (Color)

# %% [markdown]
# ## 1. color-insufficient-cc-normal
# ## 2. color-insufficient-cc-large
#
# ![ChatGPT Image Sep 23, 2025, 02_12_11 PM.png](attachment:e238a566-7eff-4ec5-be0d-e031e1f3a99d.png)
